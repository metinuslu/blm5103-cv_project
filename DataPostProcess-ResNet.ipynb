# %%
# Install & Import Libraries
import pandas as pd
import numpy as np

import os
from datetime import datetime
import warnings

# %%
# Set Other Configs
pd.options.display.float_format = '{:,.2f}'.format
warnings.filterwarnings(action="ignore")

# %%
# Set Path Configs
ROOT_PATH = os.getcwd()
DATA_PATH = os.path.join(ROOT_PATH, 'data')
IMAGE_DATA_PATH = os.path.join(DATA_PATH, 'images')
RAW_DATA_PATH = os.path.join(DATA_PATH, 'input')
PROCESSED_DATA_PATH = os.path.join(DATA_PATH, 'processed')
RESULT_DATA_PATH = os.path.join(DATA_PATH, 'result')

# %%
df_master_data = pd.read_csv(os.path.join(PROCESSED_DATA_PATH, "MasterData.csv.gz"))
df_master_data
# Out:
#      ImgId    ImgName                                              Title  \
# 0     2461   2461.jpg                                 Richard III (1912)
# 1     2544   2544.jpg                        TrÌ_dgÌ´rdsmÌ_staren (1912)
# 2     2795   2795.jpg                            Death's Marathon (1913)
# 3     2844   2844.jpg  FantÌ«mas: In the Shadow of the Guillotine (1913)
# 4     2985   2985.jpg                       The House of Darkness (1913)
# ..     ...        ...                                                ...
# 806  25555  25555.jpg                                        Nana (1934)
# 807  25580  25580.jpg                             Now and Forever (1934)
# 808  25586  25586.jpg                            Of Human Bondage (1934)
# 809  25590  25590.jpg                       The Old Fashioned Way (1934)
# 810  25607  25607.jpg                                 Operator 13 (1934)
#
#      Genre1   Genre2   Genre3  IMDBScore                           ImdbLink  \
# 0     Drama      NaN      NaN       5.70   http://www.imdb.com/title/tt2461
# 1     Drama      NaN      NaN       6.40   http://www.imdb.com/title/tt2544
# 2     Drama    Drama  Romance       6.20   http://www.imdb.com/title/tt2795
# 3     Crime    Drama      NaN       6.90   http://www.imdb.com/title/tt2844
# 4     Drama    Drama      NaN       6.10   http://www.imdb.com/title/tt2985
# ..      ...      ...      ...        ...                                ...
# 806   Drama      NaN      NaN       6.10  http://www.imdb.com/title/tt25555
# 807   Drama  Romance      NaN       6.60  http://www.imdb.com/title/tt25580
# 808   Drama  Romance      NaN       7.30  http://www.imdb.com/title/tt25586
# 809  Comedy      NaN      NaN       7.60  http://www.imdb.com/title/tt25590
# 810   Drama  History  Romance       7.90  http://www.imdb.com/title/tt25607
#
#                                                 Poster
# 0    https://images-na.ssl-images-amazon.com/images...
# 1    https://images-na.ssl-images-amazon.com/images...
# 2    https://images-na.ssl-images-amazon.com/images...
# 3    https://images-na.ssl-images-amazon.com/images...
# 4    https://images-na.ssl-images-amazon.com/images...
# ..                                                 ...
# 806  https://images-na.ssl-images-amazon.com/images...
# 807  https://images-na.ssl-images-amazon.com/images...
# 808  https://images-na.ssl-images-amazon.com/images...
# 809  https://images-na.ssl-images-amazon.com/images...
# 810  https://images-na.ssl-images-amazon.com/images...
#
# [811 rows x 9 columns]

# %%
df_img_emb_inception_v3_data = pd.read_csv(os.path.join(PROCESSED_DATA_PATH, "resnet_v2.csv.gz"))
df_img_emb_inception_v3_data
# Out:
#        ImgName    0    1    2    3    4    5    6    7    8  ...  2038  2039  \
# 0    10057.jpg 0.05 0.13 0.41 0.63 0.03 0.00 0.07 0.73 0.11  ...  0.49  0.11
# 1    10040.jpg 0.70 0.17 0.52 0.00 1.42 0.00 0.49 0.00 0.05  ...  0.00  0.00
# 2    10155.jpg 0.56 0.19 0.66 0.00 0.24 0.00 0.10 0.07 0.26  ...  0.03  0.00
# 3    10071.jpg 0.00 0.95 2.50 0.04 0.04 0.00 0.00 0.43 0.15  ...  0.10  0.00
# 4    10195.jpg 0.00 1.80 0.51 0.00 0.74 0.00 0.81 0.02 0.00  ...  0.13  0.19
# ..         ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...   ...   ...
# 992   9899.jpg 0.56 0.19 0.66 0.00 0.24 0.00 0.10 0.07 0.26  ...  0.03  0.00
# 993   9932.jpg 0.01 0.10 0.05 0.05 0.32 0.00 2.54 0.00 0.09  ...  0.00  0.00
# 994   9937.jpg 0.22 0.39 2.31 0.06 0.62 0.00 1.09 0.86 0.24  ...  0.04  0.00
# 995   9968.jpg 0.54 0.12 0.57 0.00 0.14 0.00 0.83 0.24 0.03  ...  0.00  0.00
# 996   9976.jpg 0.13 0.58 1.31 0.01 1.51 0.00 0.15 2.08 0.00  ...  0.00  0.00
#
#      2040  2041  2042  2043  2044  2045  2046  2047
# 0    0.00  0.00  0.15  0.13  0.67  0.00  0.14  0.03
# 1    0.13  0.01  2.06  0.00  1.21  0.09  0.25  0.53
# 2    0.74  0.00  0.30  0.04  0.48  0.18  0.26  0.06
# 3    0.09  0.00  1.25  0.00  0.45  0.44  0.00  0.06
# 4    0.41  0.00  0.11  0.30  0.87  0.02  0.95  0.00
# ..    ...   ...   ...   ...   ...   ...   ...   ...
# 992  0.74  0.00  0.30  0.04  0.48  0.18  0.26  0.06
# 993  0.64  0.00  0.00  0.09  3.03  0.04  0.19  0.06
# 994  0.20  0.00  0.08  0.05  2.99  0.11  0.08  0.00
# 995  0.00  0.00  0.02  0.00  1.42  0.55  0.36  0.02
# 996  0.51  0.00  0.03  0.00  0.93  0.00  0.00  0.00
#
# [997 rows x 2049 columns]

# %%
df_img_emb_inception_v3_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 997 entries, 0 to 996
# Columns: 2049 entries, ImgName to 2047
# dtypes: float64(2048), object(1)
# memory usage: 15.6+ MB

# %%
# df_img_emb_inception_v3_data['ImgId'] = df_img_emb_inception_v3_data['ImgName'].apply(lambda x: x.split('.')[0])
# del df_img_emb_inception_v3_data['ImgId']

# df_img_emb_inception_v3_data['ImgId'] = df_img_emb_inception_v3_data['ImgId'].astype('int32')
# df_img_emb_inception_v3_data['ImgId'].dtypes

# %%
df_img_emb_data = pd.merge(left=df_master_data, right=df_img_emb_inception_v3_data, on='ImgName')
df_img_emb_data
# Out:
#      ImgId    ImgName                                              Title  \
# 0     2461   2461.jpg                                 Richard III (1912)
# 1     2544   2544.jpg                        TrÌ_dgÌ´rdsmÌ_staren (1912)
# 2     2795   2795.jpg                            Death's Marathon (1913)
# 3     2844   2844.jpg  FantÌ«mas: In the Shadow of the Guillotine (1913)
# 4     2985   2985.jpg                       The House of Darkness (1913)
# ..     ...        ...                                                ...
# 806  25555  25555.jpg                                        Nana (1934)
# 807  25580  25580.jpg                             Now and Forever (1934)
# 808  25586  25586.jpg                            Of Human Bondage (1934)
# 809  25590  25590.jpg                       The Old Fashioned Way (1934)
# 810  25607  25607.jpg                                 Operator 13 (1934)
#
#      Genre1   Genre2   Genre3  IMDBScore                           ImdbLink  \
# 0     Drama      NaN      NaN       5.70   http://www.imdb.com/title/tt2461
# 1     Drama      NaN      NaN       6.40   http://www.imdb.com/title/tt2544
# 2     Drama    Drama  Romance       6.20   http://www.imdb.com/title/tt2795
# 3     Crime    Drama      NaN       6.90   http://www.imdb.com/title/tt2844
# 4     Drama    Drama      NaN       6.10   http://www.imdb.com/title/tt2985
# ..      ...      ...      ...        ...                                ...
# 806   Drama      NaN      NaN       6.10  http://www.imdb.com/title/tt25555
# 807   Drama  Romance      NaN       6.60  http://www.imdb.com/title/tt25580
# 808   Drama  Romance      NaN       7.30  http://www.imdb.com/title/tt25586
# 809  Comedy      NaN      NaN       7.60  http://www.imdb.com/title/tt25590
# 810   Drama  History  Romance       7.90  http://www.imdb.com/title/tt25607
#
#                                                 Poster    0  ...  2038  2039  \
# 0    https://images-na.ssl-images-amazon.com/images... 0.04  ...  0.12  2.28
# 1    https://images-na.ssl-images-amazon.com/images... 0.70  ...  0.67  0.00
# 2    https://images-na.ssl-images-amazon.com/images... 0.00  ...  0.00  0.00
# 3    https://images-na.ssl-images-amazon.com/images... 0.67  ...  0.21  0.00
# 4    https://images-na.ssl-images-amazon.com/images... 0.34  ...  0.12  0.17
# ..                                                 ...  ...  ...   ...   ...
# 806  https://images-na.ssl-images-amazon.com/images... 0.06  ...  0.00  0.75
# 807  https://images-na.ssl-images-amazon.com/images... 0.00  ...  0.05  0.00
# 808  https://images-na.ssl-images-amazon.com/images... 0.00  ...  0.04  0.00
# 809  https://images-na.ssl-images-amazon.com/images... 0.20  ...  0.26  0.00
# 810  https://images-na.ssl-images-amazon.com/images... 0.00  ...  0.05  0.00
#
#      2040  2041  2042  2043  2044  2045  2046  2047
# 0    0.33  0.00  0.27  0.17  0.76  0.64  0.44  0.86
# 1    0.11  0.00  0.00  0.00  3.21  0.54  0.00  0.08
# 2    0.45  0.00  0.00  0.00  0.63  0.15  0.97  0.03
# 3    0.61  0.00  0.07  0.00  2.86  0.17  0.21  0.06
# 4    0.00  0.00  0.01  1.80  2.34  0.30  0.16  0.13
# ..    ...   ...   ...   ...   ...   ...   ...   ...
# 806  0.55  0.00  2.78  0.67  0.19  0.85  0.08  0.00
# 807  0.86  0.00  0.00  0.01  0.12  1.99  0.29  0.04
# 808  0.06  0.00  1.81  0.00  0.00  0.07  0.24  0.01
# 809  0.02  0.00  1.00  0.03  0.88  0.41  0.66  0.05
# 810  0.76  0.00  0.03  0.02  0.45  0.00  0.07  0.00
#
# [811 rows x 2057 columns]

# %%
df_img_emb_data.to_csv(os.path.join(RESULT_DATA_PATH, "ImgEmbeddingwithResNet-v2.csv.gz"), compression='gzip', index=False)
