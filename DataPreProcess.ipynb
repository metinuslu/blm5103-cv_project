# %%
# Install & Import Libraries
import pandas as pd
import numpy as np

import os
from datetime import datetime
import warnings

# %%
# Set Other Configs
pd.options.display.float_format = '{:,.2f}'.format
warnings.filterwarnings(action="ignore")

# %%
# Set Path Configs
ROOT_PATH = os.getcwd()
DATA_PATH = os.path.join(ROOT_PATH, 'data')
IMAGE_DATA_PATH = os.path.join(DATA_PATH, 'images')
RAW_DATA_PATH = os.path.join(DATA_PATH, 'input')
PROCESSED_DATA_PATH = os.path.join(DATA_PATH, 'processed')

# %% [markdown]
# ### Read Movies Data

# %%
df_movies_data = pd.read_csv(os.path.join(RAW_DATA_PATH, "MovieGenre.csv"), encoding='latin-1')
df_movies_data
# Out:
#        imdbId                           Imdb Link  \
# 0      114709  http://www.imdb.com/title/tt114709
# 1      113497  http://www.imdb.com/title/tt113497
# 2      113228  http://www.imdb.com/title/tt113228
# 3      114885  http://www.imdb.com/title/tt114885
# 4      113041  http://www.imdb.com/title/tt113041
# ...       ...                                 ...
# 40103   83168   http://www.imdb.com/title/tt83168
# 40104   82875   http://www.imdb.com/title/tt82875
# 40105  815258  http://www.imdb.com/title/tt815258
# 40106   79142   http://www.imdb.com/title/tt79142
# 40107   70710   http://www.imdb.com/title/tt70710
#
#                                     Title  IMDB Score  \
# 0                        Toy Story (1995)         8.3
# 1                          Jumanji (1995)         6.9
# 2                 Grumpier Old Men (1995)         6.6
# 3                Waiting to Exhale (1995)         5.7
# 4      Father of the Bride Part II (1995)         5.9
# ...                                   ...         ...
# 40103               Tanya's Island (1980)         4.3
# 40104               Pacific Banana (1981)         4.7
# 40105  Werewolf in a Womens Prison (2006)         4.5
# 40106              Xiao zi ming da (1979)         6.5
# 40107                     Snatched (1973)         6.5
#
#                             Genre  \
# 0      Animation|Adventure|Comedy
# 1         Action|Adventure|Family
# 2                  Comedy|Romance
# 3            Comedy|Drama|Romance
# 4           Comedy|Family|Romance
# ...                           ...
# 40103                       Drama
# 40104                      Comedy
# 40105                      Horror
# 40106               Action|Comedy
# 40107        Crime|Drama|Thriller
#
#                                                   Poster
# 0      https://images-na.ssl-images-amazon.com/images...
# 1      https://images-na.ssl-images-amazon.com/images...
# 2      https://images-na.ssl-images-amazon.com/images...
# 3      https://images-na.ssl-images-amazon.com/images...
# 4      https://images-na.ssl-images-amazon.com/images...
# ...                                                  ...
# 40103  https://images-na.ssl-images-amazon.com/images...
# 40104  https://images-na.ssl-images-amazon.com/images...
# 40105  https://images-na.ssl-images-amazon.com/images...
# 40106  https://images-na.ssl-images-amazon.com/images...
# 40107                                                NaN
#
# [40108 rows x 6 columns]

# %%
df_movies_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40108 entries, 0 to 40107
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   imdbId      40108 non-null  int64
#  1   Imdb Link   40108 non-null  object
#  2   Title       40108 non-null  object
#  3   IMDB Score  40060 non-null  float64
#  4   Genre       39963 non-null  object
#  5   Poster      39383 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 1.8+ MB

# %%
df_movies_data['imdbId'] = df_movies_data['imdbId'].astype('int32')
df_movies_data['imdbId'].dtype
# Out:
# dtype('int32')

# %%
df_movies_data.sort_values(by=['imdbId'], ascending=True, inplace=True)

# %%
duplicated_movie_list = df_movies_data[df_movies_data['imdbId'].duplicated()]['imdbId'].to_list()
print("Duplicate Movies Count:", len(duplicated_movie_list))
# Out:
# Duplicate Movies Count: 593

# %%
df_movies_data[(df_movies_data['imdbId'].isin(duplicated_movie_list))].sort_values(by=['imdbId'], ascending=True)
# Out:
#         imdbId                            Imdb Link  \
# 12409    11358    http://www.imdb.com/title/tt11358
# 13003    11358    http://www.imdb.com/title/tt11358
# 12748    11439    http://www.imdb.com/title/tt11439
# 13342    11439    http://www.imdb.com/title/tt11439
# 13344    12752    http://www.imdb.com/title/tt12752
# ...        ...                                  ...
# 12707  1151309  http://www.imdb.com/title/tt1151309
# 12521  1166827  http://www.imdb.com/title/tt1166827
# 13115  1166827  http://www.imdb.com/title/tt1166827
# 13304  1219671  http://www.imdb.com/title/tt1219671
# 12710  1219671  http://www.imdb.com/title/tt1219671
#
#                                                   Title  IMDB Score  \
# 12409                                  Just Pals (1920)         6.6
# 13003                                  Just Pals (1920)         6.6
# 12748                          The Mark of Zorro (1920)         7.3
# 13342                          The Mark of Zorro (1920)         7.3
# 13344                       The Three Musketeers (1921)         7.0
# ...                                                 ...         ...
# 12707                    Bigger Stronger Faster* (2008)         7.6
# 12521                                  Zeitgeist (2007)         8.2
# 13115                                  Zeitgeist (2007)         8.2
# 13304  Allan Quatermain and the Temple of Skulls (2008)         2.6
# 12710  Allan Quatermain and the Temple of Skulls (2008)         2.6
#
#                            Genre  \
# 12409       Comedy|Drama|Western
# 13003       Comedy|Drama|Western
# 12748  Adventure|Romance|Western
# 13342  Adventure|Romance|Western
# 13344   Action|Adventure|Romance
# ...                          ...
# 12707          Documentary|Sport
# 12521        Documentary|History
# 13115        Documentary|History
# 13304   Action|Adventure|Romance
# 12710   Action|Adventure|Romance
#
#                                                   Poster
# 12409  https://images-na.ssl-images-amazon.com/images...
# 13003  https://images-na.ssl-images-amazon.com/images...
# 12748  https://images-na.ssl-images-amazon.com/images...
# 13342  https://images-na.ssl-images-amazon.com/images...
# 13344  https://images-na.ssl-images-amazon.com/images...
# ...                                                  ...
# 12707  https://images-na.ssl-images-amazon.com/images...
# 12521  https://images-na.ssl-images-amazon.com/images...
# 13115  https://images-na.ssl-images-amazon.com/images...
# 13304  https://images-na.ssl-images-amazon.com/images...
# 12710  https://images-na.ssl-images-amazon.com/images...
#
# [1186 rows x 6 columns]

# %%
df_movies_data.drop_duplicates(keep='first', inplace=True)

# %% [markdown]
# ### Read Image List

# %%
image_list = os.listdir(IMAGE_DATA_PATH)

# %%
df_images_data = pd.DataFrame(image_list, columns=['ImgName'])

df_images_data['ImgId'] = df_images_data['ImgName'].apply(lambda x: x.split('.')[0])
# df_images_data['ImgId'] = df_images_data['ImgName'].str.split('.', expand=True)[0]

df_images_data
# Out:
#        ImgName  ImgId
# 0    10040.jpg  10040
# 1    10057.jpg  10057
# 2    10071.jpg  10071
# 3    10155.jpg  10155
# 4    10195.jpg  10195
# ..         ...    ...
# 992   9899.jpg   9899
# 993   9932.jpg   9932
# 994   9937.jpg   9937
# 995   9968.jpg   9968
# 996   9976.jpg   9976
#
# [997 rows x 2 columns]

# %%
df_images_data.info()

# %%
df_images_data['ImgId'] = df_images_data['ImgId'].astype('int32')
df_images_data['ImgId'].dtype
# Out:
# dtype('int32')

# %%
df_movies_data.shape, df_images_data.shape
# Out:
# ((39515, 6), (997, 2))

# %%
df_movies_data['imdbId'].nunique(), df_images_data['ImgId'].nunique()
# Out:
# (39515, 997)

# %%
df_master_data = pd.merge(left=df_movies_data, right=df_images_data, how='inner', left_on=['imdbId'], right_on=['ImgId']).reset_index(drop=True)

# %%
df_master_data.columns = df_master_data.columns.str.replace(' ', '')
df_master_data.rename(columns={'imdbId':'ImdbId'}, inplace=True)
df_master_data
# Out:
#      ImdbId                           ImdbLink  \
# 0      2461   http://www.imdb.com/title/tt2461
# 1      2544   http://www.imdb.com/title/tt2544
# 2      2795   http://www.imdb.com/title/tt2795
# 3      2844   http://www.imdb.com/title/tt2844
# 4      2985   http://www.imdb.com/title/tt2985
# ..      ...                                ...
# 992   25580  http://www.imdb.com/title/tt25580
# 993   25586  http://www.imdb.com/title/tt25586
# 994   25590  http://www.imdb.com/title/tt25590
# 995   25601  http://www.imdb.com/title/tt25601
# 996   25607  http://www.imdb.com/title/tt25607
#
#                                                  Title  IMDBScore  \
# 0                                   Richard III (1912)        5.7
# 1                          TrÌ_dgÌ´rdsmÌ_staren (1912)        6.4
# 2                              Death's Marathon (1913)        6.2
# 3    FantÌ«mas: In the Shadow of the Guillotine (1913)        6.9
# 4                         The House of Darkness (1913)        6.1
# ..                                                 ...        ...
# 992                             Now and Forever (1934)        6.6
# 993                            Of Human Bondage (1934)        7.3
# 994                       The Old Fashioned Way (1934)        7.6
# 995                           One Night of Love (1934)        6.0
# 996                                 Operator 13 (1934)        7.9
#
#                      Genre                                             Poster  \
# 0                    Drama  https://images-na.ssl-images-amazon.com/images...
# 1                    Drama  https://images-na.ssl-images-amazon.com/images...
# 2      Short|Drama|Romance  https://images-na.ssl-images-amazon.com/images...
# 3              Crime|Drama  https://images-na.ssl-images-amazon.com/images...
# 4              Short|Drama  https://images-na.ssl-images-amazon.com/images...
# ..                     ...                                                ...
# 992          Drama|Romance  https://images-na.ssl-images-amazon.com/images...
# 993          Drama|Romance  https://images-na.ssl-images-amazon.com/images...
# 994                 Comedy  https://images-na.ssl-images-amazon.com/images...
# 995          Music|Romance  https://images-na.ssl-images-amazon.com/images...
# 996  Drama|History|Romance  https://images-na.ssl-images-amazon.com/images...
#
#        ImgName  ImgId
# 0     2461.jpg   2461
# 1     2544.jpg   2544
# 2     2795.jpg   2795
# 3     2844.jpg   2844
# 4     2985.jpg   2985
# ..         ...    ...
# 992  25580.jpg  25580
# 993  25586.jpg  25586
# 994  25590.jpg  25590
# 995  25601.jpg  25601
# 996  25607.jpg  25607
#
# [997 rows x 8 columns]

# %%
df_master_data = df_master_data.join(df_master_data['Genre'].str.split('|', expand=True))
df_master_data.rename(columns={0:'Genre1', 1:'Genre2', 2:'Genre3'}, inplace=True)
df_master_data
# Out:
#      ImdbId                           ImdbLink  \
# 0      2461   http://www.imdb.com/title/tt2461
# 1      2544   http://www.imdb.com/title/tt2544
# 2      2795   http://www.imdb.com/title/tt2795
# 3      2844   http://www.imdb.com/title/tt2844
# 4      2985   http://www.imdb.com/title/tt2985
# ..      ...                                ...
# 992   25580  http://www.imdb.com/title/tt25580
# 993   25586  http://www.imdb.com/title/tt25586
# 994   25590  http://www.imdb.com/title/tt25590
# 995   25601  http://www.imdb.com/title/tt25601
# 996   25607  http://www.imdb.com/title/tt25607
#
#                                                  Title  IMDBScore  \
# 0                                   Richard III (1912)        5.7
# 1                          TrÌ_dgÌ´rdsmÌ_staren (1912)        6.4
# 2                              Death's Marathon (1913)        6.2
# 3    FantÌ«mas: In the Shadow of the Guillotine (1913)        6.9
# 4                         The House of Darkness (1913)        6.1
# ..                                                 ...        ...
# 992                             Now and Forever (1934)        6.6
# 993                            Of Human Bondage (1934)        7.3
# 994                       The Old Fashioned Way (1934)        7.6
# 995                           One Night of Love (1934)        6.0
# 996                                 Operator 13 (1934)        7.9
#
#                      Genre                                             Poster  \
# 0                    Drama  https://images-na.ssl-images-amazon.com/images...
# 1                    Drama  https://images-na.ssl-images-amazon.com/images...
# 2      Short|Drama|Romance  https://images-na.ssl-images-amazon.com/images...
# 3              Crime|Drama  https://images-na.ssl-images-amazon.com/images...
# 4              Short|Drama  https://images-na.ssl-images-amazon.com/images...
# ..                     ...                                                ...
# 992          Drama|Romance  https://images-na.ssl-images-amazon.com/images...
# 993          Drama|Romance  https://images-na.ssl-images-amazon.com/images...
# 994                 Comedy  https://images-na.ssl-images-amazon.com/images...
# 995          Music|Romance  https://images-na.ssl-images-amazon.com/images...
# 996  Drama|History|Romance  https://images-na.ssl-images-amazon.com/images...
#
#        ImgName  ImgId  Genre1   Genre2   Genre3
# 0     2461.jpg   2461   Drama     None     None
# 1     2544.jpg   2544   Drama     None     None
# 2     2795.jpg   2795   Short    Drama  Romance
# 3     2844.jpg   2844   Crime    Drama     None
# 4     2985.jpg   2985   Short    Drama     None
# ..         ...    ...     ...      ...      ...
# 992  25580.jpg  25580   Drama  Romance     None
# 993  25586.jpg  25586   Drama  Romance     None
# 994  25590.jpg  25590  Comedy     None     None
# 995  25601.jpg  25601   Music  Romance     None
# 996  25607.jpg  25607   Drama  History  Romance
#
# [997 rows x 11 columns]

# %%
df_master_data_genre_grpby = df_master_data.groupby(by=['Genre1'], as_index=False).agg(Cnt=('ImdbId','count')).sort_values(by=['Cnt'], ascending=False)
df_master_data_genre_grpby['CntRatio'] = df_master_data_genre_grpby['Cnt'] / df_master_data.shape[0] * 100
df_master_data_genre_grpby['CumSum'] = df_master_data_genre_grpby['Cnt'].cumsum()
df_master_data_genre_grpby['CumRatio'] = df_master_data_genre_grpby['CumSum'] / df_master_data.shape[0] * 100
df_master_data_genre_grpby
# Out:
#          Genre1  Cnt  CntRatio  CumSum  CumRatio
# 7         Drama  354     35.51     354     35.51
# 4        Comedy  266     26.68     620     62.19
# 5         Crime   84      8.43     704     70.61
# 16        Short   62      6.22     766     76.83
# 1     Adventure   53      5.32     819     82.15
# 0        Action   37      3.71     856     85.86
# 2     Animation   23      2.31     879     88.16
# 3     Biography   20      2.01     899     90.17
# 6   Documentary   17      1.71     916     91.88
# 15      Romance   16      1.60     932     93.48
# 14      Mystery   12      1.20     944     94.68
# 9       Fantasy   12      1.20     956     95.89
# 11       Horror   12      1.20     968     97.09
# 18      Western   11      1.10     979     98.19
# 13      Musical    8      0.80     987     99.00
# 8        Family    3      0.30     990     99.30
# 17          War    3      0.30     993     99.60
# 12        Music    2      0.20     995     99.80
# 10      History    2      0.20     997    100.00

# %%
selected_genre_list = df_master_data_genre_grpby['Genre1'].to_list()
selected_genre_list = selected_genre_list[0:5]
selected_genre_list
# Out:
# ['Drama', 'Comedy', 'Crime', 'Short', 'Adventure']

# %%
df_master_data = df_master_data[(df_master_data['Genre1'].isin(selected_genre_list))][['ImgId', 'ImgName', 'Title', 'Genre1', 'Genre2', 'Genre3', 'IMDBScore', 'ImdbLink', 'Poster']]
df_master_data
# Out:
#      ImgId    ImgName                                              Title  \
# 0     2461   2461.jpg                                 Richard III (1912)
# 1     2544   2544.jpg                        TrÌ_dgÌ´rdsmÌ_staren (1912)
# 2     2795   2795.jpg                            Death's Marathon (1913)
# 3     2844   2844.jpg  FantÌ«mas: In the Shadow of the Guillotine (1913)
# 4     2985   2985.jpg                       The House of Darkness (1913)
# ..     ...        ...                                                ...
# 991  25555  25555.jpg                                        Nana (1934)
# 992  25580  25580.jpg                             Now and Forever (1934)
# 993  25586  25586.jpg                            Of Human Bondage (1934)
# 994  25590  25590.jpg                       The Old Fashioned Way (1934)
# 996  25607  25607.jpg                                 Operator 13 (1934)
#
#      Genre1   Genre2   Genre3  IMDBScore                           ImdbLink  \
# 0     Drama     None     None       5.70   http://www.imdb.com/title/tt2461
# 1     Drama     None     None       6.40   http://www.imdb.com/title/tt2544
# 2     Short    Drama  Romance       6.20   http://www.imdb.com/title/tt2795
# 3     Crime    Drama     None       6.90   http://www.imdb.com/title/tt2844
# 4     Short    Drama     None       6.10   http://www.imdb.com/title/tt2985
# ..      ...      ...      ...        ...                                ...
# 991   Drama     None     None       6.10  http://www.imdb.com/title/tt25555
# 992   Drama  Romance     None       6.60  http://www.imdb.com/title/tt25580
# 993   Drama  Romance     None       7.30  http://www.imdb.com/title/tt25586
# 994  Comedy     None     None       7.60  http://www.imdb.com/title/tt25590
# 996   Drama  History  Romance       7.90  http://www.imdb.com/title/tt25607
#
#                                                 Poster
# 0    https://images-na.ssl-images-amazon.com/images...
# 1    https://images-na.ssl-images-amazon.com/images...
# 2    https://images-na.ssl-images-amazon.com/images...
# 3    https://images-na.ssl-images-amazon.com/images...
# 4    https://images-na.ssl-images-amazon.com/images...
# ..                                                 ...
# 991  https://images-na.ssl-images-amazon.com/images...
# 992  https://images-na.ssl-images-amazon.com/images...
# 993  https://images-na.ssl-images-amazon.com/images...
# 994  https://images-na.ssl-images-amazon.com/images...
# 996  https://images-na.ssl-images-amazon.com/images...
#
# [819 rows x 9 columns]

# %%
df_master_data.to_csv(os.path.join(PROCESSED_DATA_PATH, "MasterData.csv"), index=False)
